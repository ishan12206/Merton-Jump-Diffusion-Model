# %% [markdown]
# Objective:
# Simulate asset price paths under the Merton jump–diffusion model and analyze how jumps affect path behaviour and return distributions relative to Black–Scholes.

# %%
import numpy as np
import matplotlib.pyplot as plt

from src.option_pricing import merton_option_price_formula
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 from src.option_pricing import merton_option_price_formula
#
# ModuleNotFoundError: No module named 'src'
